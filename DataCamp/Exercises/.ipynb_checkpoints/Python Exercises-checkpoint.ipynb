# %% [markdown]
# ### List Comprehension Two Layer

# %%
# Finish the List Comprehension that would Create this matrix 
"""
matrix = [[1, 2, 3],
          [1, 2, 3],
          [1, 2, 3]]
"""
matrix = [[col for col in range(1,4)] for row in range(3)]
matrix
# Out:
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %% [markdown]
# ### Excel File Parsing
# ![Screen%20Shot%202023-02-10%20at%201.50.39%20PM.png](attachment:Screen%20Shot%202023-02-10%20at%201.50.39%20PM.png)
